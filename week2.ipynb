# %% [markdown]
# ## Week 2: Functions, Lists, Tuples, Dictionaries, Sets

# %%
# 1. Write a function to check if a number is even.
# 2. Create a list and find the sum of all its elements.
# 3. Write a program to find the maximum and minimum in a list.
# 4. Create a program that removes duplicates from a list.(by using set)

# %%
# 5. Write a function to reverse a list.
def rev(list):
    print(list[::-1])

# %%
l= [2,2,5,12,1512,1,2,21,21,2]
rev(l)
# Out:
# [2, 21, 21, 2, 1, 1512, 12, 5, 2, 2]

# %%
# 6. Create a tuple and access its elements.
# 7. Convert a list into a tuple and vice versa.

# %%
l
# Out:
# [2, 2, 5, 12, 1512, 1, 2, 21, 21, 2]

# %%
tuple(l)
# Out:
# (2, 2, 5, 12, 1512, 1, 2, 21, 21, 2)

# %%
list(tuple(l))
# Out:
# [2, 2, 5, 12, 1512, 1, 2, 21, 21, 2]

# %%
# 6. wap to merge two dictionary
dict = {}
dict1 = {"language":"gujarti"}
dict.update(dict1)
print(dict)
# Out:
# {'language': 'gujarti'}

# %%
# 9. Write a function to count the frequency of elements in a list.
def freq(li):
    di={}
    newli = list(set(li))
    for i in newli:
        count = 0
        for j in li:
            if i ==j:
                count +=1
        di.update({i:count})
    return di

# %%
l
# Out:
# [2, 2, 5, 12, 1512, 1, 2, 21, 21, 2]

# %%
freq(l)
# Out:
# {1: 1, 2: 4, 5: 1, 1512: 1, 12: 1, 21: 2}

# %%
# 10. Create a dictionary of squares of numbers from 1 to 10.
# 11. Write a program to sort a list in ascending order.

# %%
l
# Out:
# [2, 2, 5, 12, 1512, 1, 2, 21, 21, 2]

# %%
n = len(l)
for i in range(n):
    for j in range(i+1,n):
        if l[i]>l[j]:
            l[i],l[j] = l[j],l[i]
print(l)
# Out:
# [1, 2, 2, 2, 2, 5, 12, 21, 21, 1512]

# %%
# 12. Create a program to check if a key exists in a dictionary.
# 13. Create a set and perform union, intersection, and difference.
# 14. Write a function to find common elements in two lists. (i use set intersection)
